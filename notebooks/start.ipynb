# %%
print('this is the other docker container!')
# Out:
# this is the other docker container!

# %% [markdown]
# # README
# This is a sample output

# %%
# !nvidia-smi
# Out:
# Fri May 15 05:50:36 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.12              Driver Version: 550.90.12      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               Off |   00000000:00:07.0 Off |                    0 |
# | 30%   31C    P8             25W /  300W |       2MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # This Is A Sample Header
# ## This is a smaller sample header
#
# This is a line of text

# %%
# !which python
# Out:
# /workspace/.venv/bin/python

# %%
# 1. Core Deep Learning & GPU Check
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"GPU Available: {torch.cuda.is_available()}")
print(f"GPU Name: {torch.cuda.get_device_name(0)}") # Should show NVIDIA RTX A4000

# 2. Unsloth & Acceleration Check
from unsloth import FastLanguageModel

# 3. Quantization & Fine-Tuning Stack
import bitsandbytes as bnb
import peft
import trl
import transformers
print(f"bitsandbytes version: {bnb.__version__}") # Essential for 4-bit QLoRA

# 4. Data Handling
import datasets
import pandas as pd

print("\n✅ Environment verification complete. No config errors detected.")
# Out:
# PyTorch version: 2.10.0+cu128
# GPU Available: True
# GPU Name: NVIDIA RTX A6000
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       4 print(f"GPU Available: {torch.cuda.is_available()}")
#       5 print(f"GPU Name: {torch.cuda.get_device_name(0)}") # Should show NVIDIA RTX A4000
#       6
#       7 # 2. Unsloth & Acceleration Check
# ----> 8 from unsloth import FastLanguageModel
#       9
#      10 # 3. Quantization & Fine-Tuning Stack
#      11 import bitsandbytes as bnb
#
# File /workspace/.venv/lib/python3.11/site-packages/unsloth/__init__.py:105
#      93         print(
#      94             "Unsloth: Please update Unsloth and Unsloth-Zoo to the latest version!\n"
#      95             "Do this via `pip install --upgrade --force-reinstall --no-cache-dir --no-deps unsloth unsloth_zoo`"
#      96         )
#      97         # if os.environ.get("UNSLOTH_DISABLE_AUTO_UPDATES", "0") == "0":
#      98         #     try:
#      99         #         os.system("pip install --upgrade --no-cache-dir --no-deps unsloth_zoo")
#    (...)    103         #         except:
#     104         #             raise ImportError("Unsloth: Please update unsloth_zoo via `pip install --upgrade --no-cache-dir --no-deps unsloth_zoo`")
# --> 105     import unsloth_zoo
#     106 except PackageNotFoundError:
#     107     raise ImportError(
#     108         f"Unsloth: Please install unsloth_zoo via `pip install unsloth_zoo` then retry!"
#     109     )
#
# File /workspace/.venv/lib/python3.11/site-packages/unsloth_zoo/__init__.py:289
#     286 # Log Unsloth-Zoo Utilities
#     287 os.environ["UNSLOTH_ZOO_IS_PRESENT"] = "1"
# --> 289 from .temporary_patches import (
#     290     encode_conversations_with_harmony,
#     291 )
#     292 from .rl_environments import (
#     293     check_python_modules,
#     294     create_locked_down_function,
#    (...)    298     launch_openenv,
#     299 )
#     301 # Top some pydantic warnings
#
# File /workspace/.venv/lib/python3.11/site-packages/unsloth_zoo/temporary_patches/__init__.py:18
#       1 # Unsloth Zoo - Utilities for Unsloth
#       2 # Copyright 2023-present Daniel Han-Chen, Michael Han-Chen & the Unsloth team. All rights reserved.
#       3 #
#    (...)     14 # You should have received a copy of the GNU Lesser General Public License
#      15 # along with this program.  If not, see <https://www.gnu.org/licenses/>.
# ---> 18 from .common import *
#      19 from .gemma import *
#      20 from .misc import *
#
# File /workspace/.venv/lib/python3.11/site-packages/unsloth_zoo/temporary_patches/common.py:39
#      37 import inspect
#      38 import torch
# ---> 39 inductor_config_source = inspect.getsource(torch._inductor.config)
#      41 @functools.lru_cache(1)
#      42 def determine_compile_threads():
#      43     # See https://github.com/pytorch/pytorch/blob/ab2294d8289a7757a2fc321cdefac88e2b378edf/torch/_inductor/config.py#L771
#      44     # Windows thread count = 1. See https://github.com/unslothai/unsloth-zoo/pull/187
#      45     if sys.platform == "win32": return 1
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/__init__.py:2865, in __getattr__(name)
#    2863 # Lazy modules
#    2864 if name in _lazy_modules:
# -> 2865     return importlib.import_module(f".{name}", __name__)
#    2867 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# File /opt/conda/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/_inductor/__init__.py:11
#       7 from typing import Any, IO, Literal, Optional, TYPE_CHECKING, Union
#       9 import torch.fx
# ---> 11 from .standalone_compile import CompiledArtifact  # noqa: TC001
#      14 if TYPE_CHECKING:
#      15     from torch._inductor.utils import InputType
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/_inductor/standalone_compile.py:13
#      10 from typing import Any, Literal, Optional, TYPE_CHECKING
#      12 import torch.fx
# ---> 13 from torch._dynamo.aot_compile_types import BundledAOTAutogradSerializableCallable
#      14 from torch._dynamo.utils import dynamo_timed
#      15 from torch._inductor.cpp_builder import normalize_path_separator
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/_dynamo/__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     config,
#      16     convert_frame,
#      17     eval_frame,
#      18     functional_export,
#      19     resume_execution,
#      20 )
#      21 from .backends.registry import list_backends, lookup_backend, register_backend
#      22 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/_dynamo/aot_compile.py:14
#      12 import torch
#      13 import torch.fx
# ---> 14 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      15 from torch._dynamo.graph_utils import _graph_device_type
#      16 from torch._dynamo.package import SystemInfo
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:60
#      58 from torch._dynamo.callback import CallbackTrigger
#      59 from torch._dynamo.distributed import get_compile_pg
# ---> 60 from torch._dynamo.symbolic_convert import TensorifyState
#      61 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      62 from torch._logging import structured
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:53
#      51 import torch
#      52 import torch._logging
# ---> 53 from torch._dynamo.exc import ObservedException, TensorifyScalarRestartAnalysis
#      54 from torch._guards import tracing, TracingContext
#      55 from torch._logging.structured import dump_file
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/_dynamo/exc.py:44
#      41 from torch._utils_internal import get_file_path_2
#      43 from . import config
# ---> 44 from .utils import counters
#      47 if TYPE_CHECKING:
#      48     import types
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/_dynamo/utils.py:69
#      67 import torch
#      68 import torch._functorch.config
# ---> 69 import torch.fx.experimental.symbolic_shapes
#      70 import torch.utils._pytree as pytree
#      71 from torch import fx
#
# File /workspace/.venv/lib/python3.11/site-packages/torch/fx/experimental/symbolic_shapes.py:3
#       1 from __future__ import annotations
# ----> 3 import sympy
#       4 from sympy import S
#       6 from torch._prims_common import BoolLike, FloatLike, IntLike
#
# File /workspace/.venv/lib/python3.11/site-packages/sympy/__init__.py:31
#      28 del mpmath
#      30 from sympy.release import __version__
# ---> 31 from sympy.core.cache import lazy_function
#      33 if 'dev' in __version__:
#      34     def enable_warnings():
#
# File /workspace/.venv/lib/python3.11/site-packages/sympy/core/__init__.py:4
#       1 """Core module. Provides the basic operations needed in sympy.
#       2 """
# ----> 4 from .sympify import sympify, SympifyError
#       5 from .cache import cacheit
#       6 from .assumptions import assumptions, check_assumptions, failing_assumptions, common_assumptions
#
# File /workspace/.venv/lib/python3.11/site-packages/sympy/core/sympify.py:11
#       9 from inspect import getmro
#      10 import string
# ---> 11 from sympy.core.random import choice
#      13 from .parameters import global_parameters
#      15 from sympy.utilities.iterables import iterable
#
# File /workspace/.venv/lib/python3.11/site-packages/sympy/core/random.py:25
#       1 """
#       2 When you need to use random numbers in SymPy library code, import from here
#       3 so there is only one generator working for SymPy. Imports from here should
#    (...)     23
#      24 """
# ---> 25 from sympy.utilities.iterables import is_sequence
#      26 from sympy.utilities.misc import as_int
#      28 import random as _random
#
# File /workspace/.venv/lib/python3.11/site-packages/sympy/utilities/__init__.py:15
#      11 from .lambdify import lambdify
#      13 from .decorator import threaded, xthreaded, public, memoize_property
# ---> 15 from .timeutils import timed
#      17 __all__ = [
#      18     'flatten', 'group', 'take', 'subsets', 'variations', 'numbered_symbols',
#      19     'cartes', 'capture', 'dict_merge', 'prefixes', 'postfixes', 'sift',
#    (...)     29     'timed',
#      30 ]
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1150, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:666, in _load_unlocked(spec)
# --> 666 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:
